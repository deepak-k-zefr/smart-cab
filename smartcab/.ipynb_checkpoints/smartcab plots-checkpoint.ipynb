# %%
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
c=pd.read_table("counts.txt")

# %%
c.plot()
c[90:99].mean()
c.mean()
# Out:
# 0    13.444444
# dtype: float64
# 0    12.979798
# dtype: float64

# %%
c.plot()
c[90:99].mean()
c.mean()
# Out:
# 0    28.313131
# dtype: float64

# %%
import random
random.random()
# Out:
# 0.015630253961107177

# %%
argmax_actions = {action:Qhat for action, Qhat in Q[self.state].items() if Qhat == max(Q[self.state].values())}
print argmax_actions                
random.choice(argmax_actions.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-08a57318e2e3> in <module>()
# ----> 1 argmax_actions = {action:Qhat for action, Qhat in Q[self.state].items() if Qhat == max(Q[self.state].values())}
#       2 print argmax_actions
#       3 random.choice(argmax_actions.keys())
#
# NameError: name 'self' is not defined
